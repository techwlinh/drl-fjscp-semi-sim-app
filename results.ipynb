# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
result
# Out:
#                                           experiments
# 0   {'algorithm': 'ga', 'title': 'GA Metaheuristic...
# 1   {'algorithm': 'ppo_baseline_baseline', 'title'...
# 2   {'algorithm': 'ppo_baseline_continuous_tardine...
# 3   {'algorithm': 'ppo_baseline_milestone_progress...
# 4   {'algorithm': 'ppo_baseline_pbrs', 'title': 'P...
# 5   {'algorithm': 'ppo_baseline_workload_balance',...
# 6   {'algorithm': 'ppo_enhanced_baseline', 'title'...
# 7   {'algorithm': 'ppo_enhanced_continuous_tardine...
# 8   {'algorithm': 'ppo_enhanced_milestone_progress...
# 9   {'algorithm': 'ppo_enhanced_pbrs', 'title': 'P...
# 10  {'algorithm': 'ppo_enhanced_workload_balance',...
# 11  {'algorithm': 'pso', 'title': 'PSO (Particle S...
# 12  {'algorithm': 'sso', 'title': 'SSO (Simplified...
